# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('listings.csv')
df = df.dropna(subset=['price'])
df.head()
# Out:
#        id                                              name  host_id  \
# 0    6606               Fab, private seattle urban cottage!    14942
# 1    9419               Glorious sun room w/ memory foambed    30559
# 3   25002          Beautiful Private  Spot in North Ballard   102684
# 4  119103                           Teeny Tiny Guestyhouse!   601600
# 6  226536  Serene Room in Sunny Cottage near Discovery Park   209571
#
#    host_name  neighbourhood_group     neighbourhood  latitude  longitude  \
# 0      Joyce  Other neighborhoods       Wallingford  47.65444 -122.33629
# 1  Angielena  Other neighborhoods        Georgetown  47.55017 -122.31937
# 3     Amanda              Ballard  Whittier Heights  47.67947 -122.37196
# 4        Hal  Other neighborhoods           Fremont  47.65244 -122.35108
# 6     Cheryl             Magnolia       Lawton Park  47.66133 -122.40088
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# Impute misiing values into numeric

# %%
cols_to_impute = ['minimum_nights', 'reviews_per_month', 'availability_365']
subset = df[cols_to_impute]
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
imputed_data = imputer.fit_transform(subset)
df[cols_to_impute] = imputed_data

# %%
X = df[['room_type', 'neighbourhood_group', 'minimum_nights', 'number_of_reviews',
        'reviews_per_month', 'calculated_host_listings_count', 'availability_365']].values
y = df['price'].values
y
# Out:
# array([ 99.,  66.,  86., ..., 127., 127., 176.], shape=(6008,))

# %%
ct = ColumnTransformer(
    transformers=[('encoder', OneHotEncoder(drop='first'), [0, 1])],
    remainder='passthrough'
)
X = ct.fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 ct = ColumnTransformer(
#       2     transformers=[('encoder', OneHotEncoder(drop='first'), [0, 1])],
#       3     remainder='passthrough'
#       4 )
#       5 X = ct.fit_transform(X)
#
# NameError: name 'ColumnTransformer' is not defined

# %% [markdown]
# Training and Testing Splitting

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 2
#       1 scaler = StandardScaler()
# ----> 2 X_train = scaler.fit_transform(X_train)
#       3 X_test = scaler.transform(X_test)
#
# File d:\Apps\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File d:\Apps\Lib\site-packages\sklearn\base.py:892, in TransformerMixin.fit_transform(self, X, y, **fit_params)
# ...

# %% [markdown]
# Linear Regression

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 2
#       1 regressor = LinearRegression()
# ----> 2 regressor.fit(X_train, y_train)
#
# File d:\Apps\Lib\site-packages\sklearn\base.py:1363, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1356     estimator._validate_params()
#    1358 with config_context(
#    1359     skip_parameter_validation=(
#    1360         prefer_skip_nested_validation or global_skip_validation
#    1361     )
#    1362 ):
# -> 1363     return fit_method(estimator, *args, **kwargs)
#
# File d:\Apps\Lib\site-packages\sklearn\linear_model\_base.py:618, in LinearRegression.fit(self, X, y, sample_weight)
#     614 n_jobs_ = self.n_jobs
#     616 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 618 X, y = validate_data(
#     619     self,
#     620     X,
#     621     y,
# ...

# %%
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 2
#       1 regressor = LinearRegression()
# ----> 2 regressor.fit(X_train, y_train)
#
# File d:\Apps\Lib\site-packages\sklearn\base.py:1363, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1356     estimator._validate_params()
#    1358 with config_context(
#    1359     skip_parameter_validation=(
#    1360         prefer_skip_nested_validation or global_skip_validation
#    1361     )
#    1362 ):
# -> 1363     return fit_method(estimator, *args, **kwargs)
#
# File d:\Apps\Lib\site-packages\sklearn\linear_model\_base.py:618, in LinearRegression.fit(self, X, y, sample_weight)
#     614 n_jobs_ = self.n_jobs
#     616 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 618 X, y = validate_data(
#     619     self,
#     620     X,
#     621     y,
# ...

# %%
# 9. Predict and evaluate
y_pred = regressor.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[30], line 2
#       1 # 9. Predict and evaluate
# ----> 2 y_pred = regressor.predict(X_test)
#
# File d:\Apps\Lib\site-packages\sklearn\linear_model\_base.py:298, in LinearModel.predict(self, X)
#     284 def predict(self, X):
#     285     """
#     286     Predict using the linear model.
#     287
#    (...)    296         Returns predicted values.
#     297     """
# --> 298     return self._decision_function(X)
#
# File d:\Apps\Lib\site-packages\sklearn\linear_model\_base.py:275, in LinearModel._decision_function(self, X)
#     274 def _decision_function(self, X):
# --> 275     check_is_fitted(self)
#     277     X = validate_data(self, X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     278     coef_ = self.coef_
#
# ...
